# %%
import matplotlib.pyplot as plt

marks = [50,54,59,65,68,70,73,75,81,83,88,90]

plt.hist(marks ,bins=8)
# Out:
# (array([2., 1., 0., 2., 2., 1., 2., 2.]),
#  array([50., 55., 60., 65., 70., 75., 80., 85., 90.]),
#  <BarContainer object of 8 artists>)
