# %%
import matplotlib.pyplot as plt

marks = [25,10,50,56,69,80,50,54,59,65,68,70,73,75,81,83,88,90]

plt.boxplot(marks,orientation='horizontal')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7813115ac9b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7813115acfb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7813115ac6b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7813115ad5e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7813115ad8e0>],
#  'means': []}
