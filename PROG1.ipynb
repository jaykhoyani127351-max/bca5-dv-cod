# %%
import pandas as pd
import matplotlib.pyplot as plt

name = ['Dishank','Jugal','Harshit','Jenish','Parth']
cgpa = [9,7,8,6,5]

plt.bar(name,cgpa,color=['red','yellow','orange','purple','green'])
plt.xlabel('Names')
plt.ylabel('CGPA')
# Out:
# Text(0, 0.5, 'CGPA')
